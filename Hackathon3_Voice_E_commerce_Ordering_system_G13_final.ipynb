# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %%
#@title Explanation Video
from IPython.display import HTML

HTML("""<video width="854" and height="480" controls>
  <source src="https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/Walkthrough/Hackathon_Voice_based.mp4" type="video/mp4">
</video>
""")
# Out:
# <video width="854" and height="480" controls>
#   <source src="https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/Walkthrough/Hackathon_Voice_based.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Hackathon: Voice commands based E-commerce ordering system
# The goal of the hackathon is to train your model on different types of voice data (such as studio data and your own team data) and able to place order based on user preferences.

# %% [markdown]
# ## Grading = 40 Marks

# %% [markdown]
# ### **Objectives:**
#
# Stage 0 - Obtain Features from Audio samples
#
# Stage 1 (22 Marks) - Define and train a CNN model on Studio data and deploy the model in the server
#
# Stage 2 (18 Marks) - Collect your voice samples (team data) and refine the classifier trained on Studio_data. Deploy the model in the server.

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# The data contains voice samples of classes - Zero, One, Two, Three, Four, Five. Each class is denoted by a numerical label from 0 to 5.
#
# The audio files collected in a Studio dataset contain very few noise samples and all the files are in wav format.
#
# The audio files recorded for the studio are saved with the following naming convention:
#
# ● Class Representation + user_id + sample_ID (or noise + sample_ID)
#
# > For example: The voice sample by the user b2 recorded “Zero”, it is saved as 0_b2_35.wav. Here 35 is sample ID, 2 is the user id and ‘0’ is the label of that sample.

# %%
#@title Please run the setup to download the dataset

from IPython import get_ipython
ipython = get_ipython()
  
notebook= "Hackathon3 - Voice E-commerce Ordering System" #name of the notebook

def setup():
    ipython.magic("sx wget https://cdn.iiith.talentsprint.com/aiml/Hackathon_data/B17_studio_rev_data.zip")
    ipython.magic("sx unzip B17_studio_rev_data.zip ")
    print ("Setup completed successfully")

setup()
# Out:
# Setup completed successfully

# %%
import os
import sys
import glob
import torch
import librosa
import warnings
import numpy as np
import torch.nn as nn
from time import sleep
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Stage 0:** Obtain Features from Audio samples
# ---
#
# ### Generate features from an audio sample of '.wav' format
# - Code is available to extract the features

# %%
# Caution: Do not change the default parameters
def get_features(filepath, sr=8000, n_mfcc=30, n_mels=128, frames = 15):
    # The following function contains code to produce features of the audio sample.  
    y, sr = librosa.load(filepath, sr=sr)
    D = np.abs(librosa.stft(y))**2
    S = librosa.feature.melspectrogram(S=D)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    log_S = librosa.power_to_db(S,ref=np.max)
    features = librosa.feature.mfcc(S=log_S, n_mfcc=n_mfcc)
    if features.shape[1] < frames :
        features = np.hstack((features, np.zeros((n_mfcc, frames - features.shape[1]))))
    elif features.shape[1] > frames:
        features = features[:, :frames]

    # Find 1st order delta_mfcc
    delta1_mfcc = librosa.feature.delta(features, order=1)

    # Find 2nd order delta_mfcc
    delta2_mfcc = librosa.feature.delta(features, order=2)

    # Stacking delta_mfcc features in sequence horizontally (column wise)
    features = np.hstack((delta1_mfcc.flatten(), delta2_mfcc.flatten()))

    # Increase the dimension by inserting an axis along second dimension
    features = features.flatten()[:,np.newaxis]
    
    # Convert the numpy.ndarray to a Tensor object
    features = Variable(torch.from_numpy(features)).float()
    return features

# %% [markdown]
# All the voice samples needed for training are present in the folder `"studio_data"`

# %%
# %ls
# Out:
# B17_studio_rev_data.zip  sample_data/  studio_data/

# %% [markdown]
# ##**Stage 1**:  Define and train a CNN model on Studio data and deploy the model in the server
#
# ---

# %% [markdown]
# ### a) Extract features of Studio data (4 Marks)
#
#  Load 'Studio data' and extract mfcc features
#
#  **Evaluation Criteria:**
#
#  * Complete the code in the load_data function
#  * The function should take path of the folder containing audio samples as input
#  * It should return features of all the audio samples present in the specified folder into single array (list of lists or 2-d numpy array) and their respective labels should be returned too

# %%
def load_data(folder_path):
  #YOUR CODE HERE
  #return features, labels
  features = []
  labels = []
  # Loop through all files in the folder
  for file_name in os.listdir(folder_path):
      if file_name.endswith('.wav'):
        # Load audio file
        file_path = os.path.join(folder_path, file_name)
        feature_vector = get_features(file_path)
        features.append(feature_vector.numpy())
        labels.append((int((file_name.split("/")[-1]).split("_")[0])))
  return features, labels

# %% [markdown]
# Load data from studio_data folder for extracting all features and labels

# %%
studio_recorded_features, studio_recorded_labels = load_data('/content/studio_data')

# %% [markdown]
# Use train_test_split for splitting the train and test data

# %%
# YOUR CODE HEREA!mL2578#
X_train,X_test,y_train, y_test= train_test_split(studio_recorded_features,studio_recorded_labels,test_size=0.2,random_state=40)

# %% [markdown]
# Load the dataset with DataLoader
# - Refer to [torch.utils.data.TensorDataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.TensorDataset)
# - Refer to [torch.utils.data.DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)

# %%
# YOUR CODE HERE for the DataLoader
from torch.utils.data import DataLoader, TensorDataset
batch_size = 28

train_set = torch.utils.data.TensorDataset(torch.FloatTensor(X_train), torch.LongTensor(y_train))
test_set = torch.utils.data.TensorDataset(torch.FloatTensor(X_test), torch.LongTensor(y_test))

#loading the train dataset

train_loader = torch.utils.data.DataLoader(train_set,batch_size= batch_size, shuffle= True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size= batch_size, shuffle= True)

# %%
torch.FloatTensor(X_train).shape
# Out:
# torch.Size([3183, 900, 1])

# %% [markdown]
# ### b) Define your CNN architecture (4 Marks)
#
# [Hint](https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html)

# %%
## Define your CNN Architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        # Sample Convolution Layer 1 
        
        self.conv1 = nn.Conv1d(in_channels=900, out_channels=400, kernel_size=1)
        self.bn1 = nn.BatchNorm1d(400)
        self.relu1 = nn.ReLU()

        # Sample Maxpool for the Convolutional Layer 1
        self.maxpool1 = nn.MaxPool1d(kernel_size=1)

        # Sample Dropout Layer
        self.dropout = nn.Dropout(p=0.25)

        # YOUR CODE HERE for defining more number of Convolutional layers with Maxpool as required (Hint: Use at least 2 more convolutional layers for better performance)
        self.conv2 = nn.Conv1d(in_channels=400,out_channels=200, kernel_size=1) 
        self.bn2 = nn.BatchNorm1d(200)
        self.relu2 = nn.ReLU()
        self.maxpool2 = nn.MaxPool1d(kernel_size=1)
        
        self.conv3 = nn.Conv1d(in_channels=200, out_channels=100, kernel_size=1) 
        self.bn3 = nn.BatchNorm1d(100)
        self.relu3 = nn.ReLU()
        self.maxpool3 = nn.MaxPool1d(kernel_size=1)
        # YOUR CODE HERE for defining the Fully Connected Layer and also define LogSoftmax

        self.fc1 = nn.Linear(100,50)
        self.fc2 = nn.Linear(50,25)
        self.fc3 = nn.Linear(25,6)
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
        #print('x size', x.size(0))
        out = self.maxpool1(self.relu1(self.bn1(self.conv1(x))))
        out = self.dropout(out)


        out = self.maxpool2(self.relu2(self.bn2(self.conv2(out))))
        out = self.dropout(out)
        
        out = self.maxpool3(self.relu3(self.bn3(self.conv3(out))))
        out = self.dropout(out)
        #print('Cnn3 shape', out.shape)
        
        #out = out.view(x.size(0), 200 * 8 * 8)
        #out = out.view(out.size(0), -1)
        out = out.view(-1, 100)
        #print('view shape', out.shape)
        #out = self.dropout1(nn.functional.relu(self.fc1(out)))
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        
        # YOUR CODE HERE for returning the output of LogSoftmax after applying Fully Connected Layer
        out = self.logsoftmax(out)
        return out

# %%
# To run the training on GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
model = Net()
model = model.to(device)

#criterion = # YOUR CODE HERE : Explore and declare loss function
criterion = nn.CrossEntropyLoss()

#optimizer = # YOUR CODE HERE : Explore on the optimizer and define with the learning rate
optimizer = optim.Adam(model.parameters(), lr = 0.001)

# %% [markdown]
# ### c) Train and classify on the studio_data (3 Marks)
#
# The goal here is to train the Model on voice samples collected in studio data and validate it continuously to calculate the loss and accuracy for the train dataset across each epoch.
#
# Iterate over images in the train_loader and perform the following steps.
#
# 1. First, zero out the gradients using zero_grad()
#
# 2. Pass the data to the model. Convert the data to GPU before passing data  to the model
#
# 3. Calculate the loss using a Loss function
#
# 4. Perform Backward pass using backward() to update the weights
#
# 5. Optimize and predict by using the torch.max()
#
# 6. Calculate the accuracy of the train dataset

# %%
# No of Epochs
epoch = 1

# keeping the network in train mode
# model.train()
# train_losses,  train_accuracy = [], []

# # Loop for no of epochs
# for e in range(epoch):
#     train_loss = 0
#     correct = 0
#     # Iterate through all the batches in each epoch
#     for voice, labels in train_loader:
#       voice = voice.to(device)
#       labels = labels.to(device)
#       optimizer.zero_grad()
#       outputs = model(voice)
#       loss = criterion(outputs, labels)
#       train_loss += loss.item()
#       loss.backward()
#       optimizer.step()
#       _, predicted = torch.max(outputs, 1)
#       correct += (predicted == labels).sum().item()
#     train_losses.append(train_loss/len(X_train))
#     train_accuracy.append(100 * correct/len(X_train))
#     print('epoch: {}, Train Loss:{:.6f} Train Accuracy: {:.2f} '.format(e+1,train_losses[-1], train_accuracy[-1]))

# %%
# YOUR CODE HERE. This will take time

# Record loss and accuracy of the train dataset
def train_model(num_epochs, model,train_loader,train_set):
  model.train()
  #Define the lists to store the results of loss and accuracy
  train_loss, train_accuracy = [],[] 
  for epoch in range(num_epochs):
    correct, iter_loss = 0, 0.0
    for (inputs, labels) in train_loader:
      inputs, labels = inputs.to(device), labels.to(device)
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, labels)
      iter_loss += loss.item()
      loss.backward()
      optimizer.step()
      _, predicted = torch.max(outputs, 1)
      correct += (predicted == labels).sum()
    train_loss.append(iter_loss/len(train_set))
    train_accuracy.append((100 * correct / len(train_set)))
    print('Epoch {}/{}, Training Loss: {:.3f}, Training Accuracy: {:.3f}'.format(epoch+1, num_epochs, train_loss[-1], train_accuracy[-1]))
  return model

# %%
trained_model = train_model(20,model,train_loader, train_set)
# Out:
# Epoch 1/20, Training Loss: 0.054, Training Accuracy: 37.606
# Epoch 2/20, Training Loss: 0.038, Training Accuracy: 57.053
# Epoch 3/20, Training Loss: 0.032, Training Accuracy: 65.253
# Epoch 4/20, Training Loss: 0.029, Training Accuracy: 67.923
# Epoch 5/20, Training Loss: 0.026, Training Accuracy: 72.604
# Epoch 6/20, Training Loss: 0.024, Training Accuracy: 76.249
# Epoch 7/20, Training Loss: 0.022, Training Accuracy: 77.160
# Epoch 8/20, Training Loss: 0.020, Training Accuracy: 80.773
# Epoch 9/20, Training Loss: 0.019, Training Accuracy: 80.867
# Epoch 10/20, Training Loss: 0.017, Training Accuracy: 82.532
# Epoch 11/20, Training Loss: 0.016, Training Accuracy: 84.354
# Epoch 12/20, Training Loss: 0.016, Training Accuracy: 84.386
# Epoch 13/20, Training Loss: 0.016, Training Accuracy: 83.412
# Epoch 14/20, Training Loss: 0.015, Training Accuracy: 85.328
# Epoch 15/20, Training Loss: 0.013, Training Accuracy: 87.842
# Epoch 16/20, Training Loss: 0.014, Training Accuracy: 86.773
# Epoch 17/20, Training Loss: 0.012, Training Accuracy: 87.653
# Epoch 18/20, Training Loss: 0.013, Training Accuracy: 88.596
# Epoch 19/20, Training Loss: 0.012, Training Accuracy: 89.098
# Epoch 20/20, Training Loss: 0.011, Training Accuracy: 89.035

# %% [markdown]
# ### d) Testing Evaluation for CNN model (3 Marks)
#
# Evaluate model with the given test data
#
# 1. Transform and load the test images.
#
# 2. Pass the test data through the model (network) to get the outputs
#
# 3. Get the predictions from a maximum value using torch.max
#
# 4. Compare with the actual labels and get the count of the correct labels
#
# 5. Calculate the accuracy based on the count of correct labels
#
# ### **Expected testing accuracy is above 80%**

# %%
# YOUR CODE HERE to test the model
def test_model(model, test_loader, test_size):
  model.eval()
  test_accuracy = 0
  test_labels, test_predictions = [], []
  for inputs, labels in test_loader:
    
    inputs = inputs.to(device)
    labels = labels.to(device)
    output = model(inputs)
    _, predicted = torch.max(output, 1)
    test_accuracy += (predicted == labels).sum().item()
    test_labels.extend(labels)
    test_predictions.extend(predicted)
  accuracy = 100 * (test_accuracy/len(test_set))
  print( " Accuracy of test data" , accuracy)
  return [i.item() for i in test_labels], [i.item() for i in test_predictions]

# %%
test_labels, test_predictions = test_model(trained_model, test_loader, test_set)
# Out:
#  Accuracy of test data 84.17085427135679

# %% [markdown]
# ### e) Save and download your model (2 Marks)
#
# **Save your model trained on studio data**
#
# * Save the state dictionary of the classifier (use pytorch only), It will be useful in
# integrating model to the web application
#
#  [Hint](https://pytorch.org/tutorials/beginner/saving_loading_models.html)

# %%
### YOUR CODE HERE for saving the CNN model
state = {'net_dict' : trained_model.state_dict()}
torch.save(state, 'studio_model.t1')

# %% [markdown]
# Download your trained model using the code below
# * Give the path of model file to download through the browser

# %%
from google.colab import files
files.download('studio_model.t1')

# %% [markdown]
# ### f) Deploy and evaluate your model trained on Studio Data in the server (6 Marks).
#
# (This can be done on the day of the Hackathon once the login username and password provided by the mentors in the lab)
#
# Deploy your model on the server, check the hackathon document (2-Server Access and File transfer For Voice based e-commerce ordering.pdf) for details.
#
# To order product in user interface, go through the document (3-Hackathon_II Application Interface Documentation.pdf) for details.
#
#
# **Evaluation Criteria: Four consecutive utterances should be predicted correctly by the model**
#
# - There are two stages in the e-commerce ordering application
#     - Ordering Product
#     - Selecting the e-commerce platform
# - If both the stages are cleared as per the evaluation criteria you will get
# complete marks Otherwise, you will see a reduction in the marks

# %% [markdown]
# ## **Stage 2:** Collect your voice samples and refine the classifier trained on studio_data and Team_data
# ---

# %% [markdown]
# ### a) Collect your Team Voice Samples and extract features (6 Marks)
#
# (This can be done on the day of the Hackathon once the login username and password is given by mentors in the lab)
#
# * In order to collect the team data, ensure the server is active (2-Server Access and File transfer For Voice based e-commerce ordering.pdf)
#
# * Refer document "3-Hackathon_II Application Interface Documentation.pdf" for collecting your team voice samples. These will get stored in your server
#
# **Evaluation Criteria:**
# * Load 'Team_data' and extract features
# * Combine features of team data with the extracted features of studio data
# * Split the combined features into train and test data
# * Load the dataset with DataLoader

# %%
# !mkdir team_data

# %%
# Replace <YOUR_GROUP_ID> with your Username given in the lab
# !wget -r -A .wav https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/ -nH --cut-dirs=100  -P ./team_data
# Out:
# --2023-04-04 14:55:59--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/
# Resolving aiml-sandbox1.talentsprint.com (aiml-sandbox1.talentsprint.com)... 139.162.203.12
# Connecting to aiml-sandbox1.talentsprint.com (aiml-sandbox1.talentsprint.com)|139.162.203.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./team_data/index.html.tmp’
#
# index.html.tmp          [ <=>                ]  22.43K  --.-KB/s    in 0s
#
# 2023-04-04 14:55:59 (304 MB/s) - ‘./team_data/index.html.tmp’ saved [22971]
#
# Loading robots.txt; please ignore errors.
# --2023-04-04 14:55:59--  https://aiml-sandbox1.talentsprint.com/robots.txt
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-04-04 14:55:59 ERROR 404: Not Found.
#
# Removing ./team_data/index.html.tmp since it should be rejected.
#
# --2023-04-04 14:55:59--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 502 Bad Gateway
# 2023-04-04 14:56:00 ERROR 502: Bad Gateway.
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680282895.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680282895.wav’
#
# 0_b20h2g13_16802828 100%[===================>]  88.09K  --.-KB/s    in 0.09s
#
# 2023-04-04 14:56:00 (929 KB/s) - ‘./team_data/0_b20h2g13_1680282895.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680283028.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680283028.wav’
#
# 0_b20h2g13_16802830 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:00 (16.8 MB/s) - ‘./team_data/0_b20h2g13_1680283028.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680283188.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680283188.wav’
#
# 0_b20h2g13_16802831 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:00 (24.7 MB/s) - ‘./team_data/0_b20h2g13_1680283188.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680342152.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680342152.wav’
#
# 0_b20h2g13_16803421 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:00 (39.6 MB/s) - ‘./team_data/0_b20h2g13_1680342152.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343601.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343601.wav’
#
# 0_b20h2g13_16803436 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:00 (19.5 MB/s) - ‘./team_data/0_b20h2g13_1680343601.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343673.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343673.wav’
#
# 0_b20h2g13_16803436 100%[===================>]  88.09K  --.-KB/s    in 0.01s
#
# 2023-04-04 14:56:00 (8.22 MB/s) - ‘./team_data/0_b20h2g13_1680343673.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343681.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343681.wav’
#
# 0_b20h2g13_16803436 100%[===================>]  88.09K  --.-KB/s    in 0.01s
#
# 2023-04-04 14:56:00 (5.74 MB/s) - ‘./team_data/0_b20h2g13_1680343681.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343737.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343737.wav’
#
# 0_b20h2g13_16803437 100%[===================>]  88.09K  --.-KB/s    in 0.02s
#
# 2023-04-04 14:56:00 (5.72 MB/s) - ‘./team_data/0_b20h2g13_1680343737.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:00--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343811.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343811.wav’
#
# 0_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.009s
#
# 2023-04-04 14:56:01 (9.22 MB/s) - ‘./team_data/0_b20h2g13_1680343811.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343853.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343853.wav’
#
# 0_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:01 (18.5 MB/s) - ‘./team_data/0_b20h2g13_1680343853.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343885.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343885.wav’
#
# 0_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.009s
#
# 2023-04-04 14:56:01 (9.48 MB/s) - ‘./team_data/0_b20h2g13_1680343885.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343926.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343926.wav’
#
# 0_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:01 (30.0 MB/s) - ‘./team_data/0_b20h2g13_1680343926.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680343994.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680343994.wav’
#
# 0_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:01 (19.0 MB/s) - ‘./team_data/0_b20h2g13_1680343994.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680344016.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680344016.wav’
#
# 0_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:01 (34.5 MB/s) - ‘./team_data/0_b20h2g13_1680344016.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680344040.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680344040.wav’
#
# 0_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:01 (34.0 MB/s) - ‘./team_data/0_b20h2g13_1680344040.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680349626.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680349626.wav’
#
# 0_b20h2g13_16803496 100%[===================>]  88.09K  --.-KB/s    in 0.007s
#
# 2023-04-04 14:56:01 (13.2 MB/s) - ‘./team_data/0_b20h2g13_1680349626.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:01--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680349708.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680349708.wav’
#
# 0_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.007s
#
# 2023-04-04 14:56:02 (12.0 MB/s) - ‘./team_data/0_b20h2g13_1680349708.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680349733.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680349733.wav’
#
# 0_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.01s
#
# 2023-04-04 14:56:02 (7.95 MB/s) - ‘./team_data/0_b20h2g13_1680349733.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680349763.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680349763.wav’
#
# 0_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:02 (26.0 MB/s) - ‘./team_data/0_b20h2g13_1680349763.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680352872.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680352872.wav’
#
# 0_b20h2g13_16803528 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:02 (35.1 MB/s) - ‘./team_data/0_b20h2g13_1680352872.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680352907.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680352907.wav’
#
# 0_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:02 (29.3 MB/s) - ‘./team_data/0_b20h2g13_1680352907.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680352940.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680352940.wav’
#
# 0_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:02 (52.6 MB/s) - ‘./team_data/0_b20h2g13_1680352940.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680352962.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680352962.wav’
#
# 0_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:02 (31.1 MB/s) - ‘./team_data/0_b20h2g13_1680352962.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680352985.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680352985.wav’
#
# 0_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:02 (35.3 MB/s) - ‘./team_data/0_b20h2g13_1680352985.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680353013.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680353013.wav’
#
# 0_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:02 (41.1 MB/s) - ‘./team_data/0_b20h2g13_1680353013.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680353044.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680353044.wav’
#
# 0_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:02 (47.2 MB/s) - ‘./team_data/0_b20h2g13_1680353044.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:02--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680353069.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680353069.wav’
#
# 0_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:03 (75.5 MB/s) - ‘./team_data/0_b20h2g13_1680353069.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680353095.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680353095.wav’
#
# 0_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:03 (61.9 MB/s) - ‘./team_data/0_b20h2g13_1680353095.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/0_b20h2g13_1680353134.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/0_b20h2g13_1680353134.wav’
#
# 0_b20h2g13_16803531 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:03 (27.9 MB/s) - ‘./team_data/0_b20h2g13_1680353134.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680282924.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680282924.wav’
#
# 1_b20h2g13_16802829 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:03 (23.6 MB/s) - ‘./team_data/1_b20h2g13_1680282924.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680283049.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680283049.wav’
#
# 1_b20h2g13_16802830 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:03 (27.2 MB/s) - ‘./team_data/1_b20h2g13_1680283049.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680283198.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680283198.wav’
#
# 1_b20h2g13_16802831 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:03 (69.2 MB/s) - ‘./team_data/1_b20h2g13_1680283198.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680342161.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680342161.wav’
#
# 1_b20h2g13_16803421 100%[===================>]  88.09K  --.-KB/s    in 0.06s
#
# 2023-04-04 14:56:03 (1.42 MB/s) - ‘./team_data/1_b20h2g13_1680342161.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343605.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343605.wav’
#
# 1_b20h2g13_16803436 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:03 (24.5 MB/s) - ‘./team_data/1_b20h2g13_1680343605.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343691.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 98392 (96K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343691.wav’
#
# 1_b20h2g13_16803436 100%[===================>]  96.09K  --.-KB/s    in 0.006s
#
# 2023-04-04 14:56:03 (16.4 MB/s) - ‘./team_data/1_b20h2g13_1680343691.wav’ saved [98392/98392]
#
# --2023-04-04 14:56:03--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343743.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343743.wav’
#
# 1_b20h2g13_16803437 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:04 (27.2 MB/s) - ‘./team_data/1_b20h2g13_1680343743.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343818.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343818.wav’
#
# 1_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:04 (27.2 MB/s) - ‘./team_data/1_b20h2g13_1680343818.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343856.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343856.wav’
#
# 1_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:04 (17.3 MB/s) - ‘./team_data/1_b20h2g13_1680343856.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343883.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343883.wav’
#
# 1_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:04 (87.7 MB/s) - ‘./team_data/1_b20h2g13_1680343883.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343887.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343887.wav’
#
# 1_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:04 (35.7 MB/s) - ‘./team_data/1_b20h2g13_1680343887.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343928.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343928.wav’
#
# 1_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:04 (89.4 MB/s) - ‘./team_data/1_b20h2g13_1680343928.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343932.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343932.wav’
#
# 1_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:04 (67.5 MB/s) - ‘./team_data/1_b20h2g13_1680343932.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680343995.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680343995.wav’
#
# 1_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:04 (51.6 MB/s) - ‘./team_data/1_b20h2g13_1680343995.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680344018.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680344018.wav’
#
# 1_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:04 (33.2 MB/s) - ‘./team_data/1_b20h2g13_1680344018.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680344041.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680344041.wav’
#
# 1_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:04 (23.1 MB/s) - ‘./team_data/1_b20h2g13_1680344041.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:04--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680349628.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680349628.wav’
#
# 1_b20h2g13_16803496 100%[===================>]  88.09K  --.-KB/s    in 0.008s
#
# 2023-04-04 14:56:05 (10.3 MB/s) - ‘./team_data/1_b20h2g13_1680349628.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680349709.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680349709.wav’
#
# 1_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:05 (50.8 MB/s) - ‘./team_data/1_b20h2g13_1680349709.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680349734.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680349734.wav’
#
# 1_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:05 (27.1 MB/s) - ‘./team_data/1_b20h2g13_1680349734.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680349764.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680349764.wav’
#
# 1_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:05 (34.3 MB/s) - ‘./team_data/1_b20h2g13_1680349764.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680352883.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680352883.wav’
#
# 1_b20h2g13_16803528 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:05 (56.6 MB/s) - ‘./team_data/1_b20h2g13_1680352883.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680352915.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680352915.wav’
#
# 1_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:05 (60.9 MB/s) - ‘./team_data/1_b20h2g13_1680352915.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680352943.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680352943.wav’
#
# 1_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:05 (26.7 MB/s) - ‘./team_data/1_b20h2g13_1680352943.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680352966.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680352966.wav’
#
# 1_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:05 (48.4 MB/s) - ‘./team_data/1_b20h2g13_1680352966.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680352987.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680352987.wav’
#
# 1_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:05 (46.4 MB/s) - ‘./team_data/1_b20h2g13_1680352987.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680353015.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680353015.wav’
#
# 1_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.008s
#
# 2023-04-04 14:56:05 (10.3 MB/s) - ‘./team_data/1_b20h2g13_1680353015.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:05--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680353046.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680353046.wav’
#
# 1_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:06 (46.9 MB/s) - ‘./team_data/1_b20h2g13_1680353046.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680353071.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680353071.wav’
#
# 1_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:06 (38.1 MB/s) - ‘./team_data/1_b20h2g13_1680353071.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680353097.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680353097.wav’
#
# 1_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:06 (51.0 MB/s) - ‘./team_data/1_b20h2g13_1680353097.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/1_b20h2g13_1680353122.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/1_b20h2g13_1680353122.wav’
#
# 1_b20h2g13_16803531 100%[===================>]  88.09K  --.-KB/s    in 0.04s
#
# 2023-04-04 14:56:06 (2.42 MB/s) - ‘./team_data/1_b20h2g13_1680353122.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680282966.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680282966.wav’
#
# 2_b20h2g13_16802829 100%[===================>]  88.09K  --.-KB/s    in 0.04s
#
# 2023-04-04 14:56:06 (2.19 MB/s) - ‘./team_data/2_b20h2g13_1680282966.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680283112.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680283112.wav’
#
# 2_b20h2g13_16802831 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:06 (25.4 MB/s) - ‘./team_data/2_b20h2g13_1680283112.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680342175.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680342175.wav’
#
# 2_b20h2g13_16803421 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:06 (26.1 MB/s) - ‘./team_data/2_b20h2g13_1680342175.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343613.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343613.wav’
#
# 2_b20h2g13_16803436 100%[===================>]  88.09K  --.-KB/s    in 0.01s
#
# 2023-04-04 14:56:06 (7.27 MB/s) - ‘./team_data/2_b20h2g13_1680343613.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:06--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343699.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343699.wav’
#
# 2_b20h2g13_16803436 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:07 (20.1 MB/s) - ‘./team_data/2_b20h2g13_1680343699.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343747.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 82008 (80K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343747.wav’
#
# 2_b20h2g13_16803437 100%[===================>]  80.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:07 (48.3 MB/s) - ‘./team_data/2_b20h2g13_1680343747.wav’ saved [82008/82008]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343822.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343822.wav’
#
# 2_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:07 (16.6 MB/s) - ‘./team_data/2_b20h2g13_1680343822.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343858.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343858.wav’
#
# 2_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:07 (19.4 MB/s) - ‘./team_data/2_b20h2g13_1680343858.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343888.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343888.wav’
#
# 2_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:07 (31.8 MB/s) - ‘./team_data/2_b20h2g13_1680343888.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343891.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343891.wav’
#
# 2_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:07 (56.7 MB/s) - ‘./team_data/2_b20h2g13_1680343891.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343929.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343929.wav’
#
# 2_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:07 (33.3 MB/s) - ‘./team_data/2_b20h2g13_1680343929.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343937.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343937.wav’
#
# 2_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:07 (76.3 MB/s) - ‘./team_data/2_b20h2g13_1680343937.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680343997.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680343997.wav’
#
# 2_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:07 (54.7 MB/s) - ‘./team_data/2_b20h2g13_1680343997.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680344020.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680344020.wav’
#
# 2_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:07 (37.2 MB/s) - ‘./team_data/2_b20h2g13_1680344020.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:07--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680344043.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680344043.wav’
#
# 2_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:08 (40.5 MB/s) - ‘./team_data/2_b20h2g13_1680344043.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680349630.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680349630.wav’
#
# 2_b20h2g13_16803496 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:08 (17.5 MB/s) - ‘./team_data/2_b20h2g13_1680349630.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680349711.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680349711.wav’
#
# 2_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:08 (29.1 MB/s) - ‘./team_data/2_b20h2g13_1680349711.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680349740.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680349740.wav’
#
# 2_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:08 (18.8 MB/s) - ‘./team_data/2_b20h2g13_1680349740.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680349766.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680349766.wav’
#
# 2_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:08 (36.6 MB/s) - ‘./team_data/2_b20h2g13_1680349766.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680352888.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680352888.wav’
#
# 2_b20h2g13_16803528 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:08 (33.8 MB/s) - ‘./team_data/2_b20h2g13_1680352888.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680352918.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680352918.wav’
#
# 2_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:08 (83.4 MB/s) - ‘./team_data/2_b20h2g13_1680352918.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680352946.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680352946.wav’
#
# 2_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:08 (107 MB/s) - ‘./team_data/2_b20h2g13_1680352946.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680352968.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680352968.wav’
#
# 2_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:08 (46.3 MB/s) - ‘./team_data/2_b20h2g13_1680352968.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:08--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680352990.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680352990.wav’
#
# 2_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:09 (89.3 MB/s) - ‘./team_data/2_b20h2g13_1680352990.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680353017.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680353017.wav’
#
# 2_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:09 (32.0 MB/s) - ‘./team_data/2_b20h2g13_1680353017.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680353048.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680353048.wav’
#
# 2_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:09 (57.9 MB/s) - ‘./team_data/2_b20h2g13_1680353048.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680353072.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680353072.wav’
#
# 2_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:09 (40.0 MB/s) - ‘./team_data/2_b20h2g13_1680353072.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680353098.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680353098.wav’
#
# 2_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:09 (55.2 MB/s) - ‘./team_data/2_b20h2g13_1680353098.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/2_b20h2g13_1680353125.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/2_b20h2g13_1680353125.wav’
#
# 2_b20h2g13_16803531 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:09 (60.2 MB/s) - ‘./team_data/2_b20h2g13_1680353125.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/3_b20h2g13_1680282985.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/3_b20h2g13_1680282985.wav’
#
# 3_b20h2g13_16802829 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:09 (24.2 MB/s) - ‘./team_data/3_b20h2g13_1680282985.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/3_b20h2g13_1680283141.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/3_b20h2g13_1680283141.wav’
#
# 3_b20h2g13_16802831 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:09 (44.6 MB/s) - ‘./team_data/3_b20h2g13_1680283141.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/3_b20h2g13_1680342190.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/3_b20h2g13_1680342190.wav’
#
# 3_b20h2g13_16803421 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:09 (136 MB/s) - ‘./team_data/3_b20h2g13_1680342190.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:09--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/3_b20h2g13_1680343618.wav
# ...
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/4_b20h2g13_1680353102.wav’
#
# 4_b20h2g13_16803531 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:15 (40.7 MB/s) - ‘./team_data/4_b20h2g13_1680353102.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:15--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/4_b20h2g13_1680353128.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/4_b20h2g13_1680353128.wav’
#
# 4_b20h2g13_16803531 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:15 (40.5 MB/s) - ‘./team_data/4_b20h2g13_1680353128.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:15--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680283006.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680283006.wav’
#
# 5_b20h2g13_16802830 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:15 (30.7 MB/s) - ‘./team_data/5_b20h2g13_1680283006.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:15--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680283167.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680283167.wav’
#
# 5_b20h2g13_16802831 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:16 (36.6 MB/s) - ‘./team_data/5_b20h2g13_1680283167.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680342210.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680342210.wav’
#
# 5_b20h2g13_16803422 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:16 (24.9 MB/s) - ‘./team_data/5_b20h2g13_1680342210.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343642.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343642.wav’
#
# 5_b20h2g13_16803436 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:16 (44.0 MB/s) - ‘./team_data/5_b20h2g13_1680343642.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343720.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343720.wav’
#
# 5_b20h2g13_16803437 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:16 (17.7 MB/s) - ‘./team_data/5_b20h2g13_1680343720.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343764.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343764.wav’
#
# 5_b20h2g13_16803437 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:16 (66.1 MB/s) - ‘./team_data/5_b20h2g13_1680343764.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343834.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343834.wav’
#
# 5_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:16 (32.2 MB/s) - ‘./team_data/5_b20h2g13_1680343834.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343864.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343864.wav’
#
# 5_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.008s
#
# 2023-04-04 14:56:16 (11.1 MB/s) - ‘./team_data/5_b20h2g13_1680343864.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343893.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343893.wav’
#
# 5_b20h2g13_16803438 100%[===================>]  88.09K  --.-KB/s    in 0.01s
#
# 2023-04-04 14:56:16 (8.04 MB/s) - ‘./team_data/5_b20h2g13_1680343893.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343910.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343910.wav’
#
# 5_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:16 (33.1 MB/s) - ‘./team_data/5_b20h2g13_1680343910.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:16--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343935.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343935.wav’
#
# 5_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:17 (44.1 MB/s) - ‘./team_data/5_b20h2g13_1680343935.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680343950.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680343950.wav’
#
# 5_b20h2g13_16803439 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:17 (25.5 MB/s) - ‘./team_data/5_b20h2g13_1680343950.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680344002.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680344002.wav’
#
# 5_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:17 (39.8 MB/s) - ‘./team_data/5_b20h2g13_1680344002.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680344024.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680344024.wav’
#
# 5_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.003s
#
# 2023-04-04 14:56:17 (26.5 MB/s) - ‘./team_data/5_b20h2g13_1680344024.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680344047.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680344047.wav’
#
# 5_b20h2g13_16803440 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:17 (42.5 MB/s) - ‘./team_data/5_b20h2g13_1680344047.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680349635.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680349635.wav’
#
# 5_b20h2g13_16803496 100%[===================>]  88.09K  --.-KB/s    in 0.01s
#
# 2023-04-04 14:56:17 (7.27 MB/s) - ‘./team_data/5_b20h2g13_1680349635.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680349716.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680349716.wav’
#
# 5_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:17 (22.9 MB/s) - ‘./team_data/5_b20h2g13_1680349716.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680349746.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680349746.wav’
#
# 5_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.004s
#
# 2023-04-04 14:56:17 (23.2 MB/s) - ‘./team_data/5_b20h2g13_1680349746.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680349770.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680349770.wav’
#
# 5_b20h2g13_16803497 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:17 (40.1 MB/s) - ‘./team_data/5_b20h2g13_1680349770.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680352901.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680352901.wav’
#
# 5_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0s
#
# 2023-04-04 14:56:17 (268 MB/s) - ‘./team_data/5_b20h2g13_1680352901.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:17--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680352934.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680352934.wav’
#
# 5_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:18 (75.3 MB/s) - ‘./team_data/5_b20h2g13_1680352934.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680352957.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680352957.wav’
#
# 5_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:18 (83.3 MB/s) - ‘./team_data/5_b20h2g13_1680352957.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680352977.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680352977.wav’
#
# 5_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:18 (51.2 MB/s) - ‘./team_data/5_b20h2g13_1680352977.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680352995.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680352995.wav’
#
# 5_b20h2g13_16803529 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:18 (40.2 MB/s) - ‘./team_data/5_b20h2g13_1680352995.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680353022.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680353022.wav’
#
# 5_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:18 (67.7 MB/s) - ‘./team_data/5_b20h2g13_1680353022.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680353053.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680353053.wav’
#
# 5_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:18 (109 MB/s) - ‘./team_data/5_b20h2g13_1680353053.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680353078.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680353078.wav’
#
# 5_b20h2g13_16803530 100%[===================>]  88.09K  --.-KB/s    in 0.001s
#
# 2023-04-04 14:56:18 (76.0 MB/s) - ‘./team_data/5_b20h2g13_1680353078.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680353103.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680353103.wav’
#
# 5_b20h2g13_16803531 100%[===================>]  88.09K  --.-KB/s    in 0.002s
#
# 2023-04-04 14:56:18 (43.7 MB/s) - ‘./team_data/5_b20h2g13_1680353103.wav’ saved [90200/90200]
#
# --2023-04-04 14:56:18--  https://aiml-sandbox1.talentsprint.com/audio_recorder/b20h2g13/team_data/5_b20h2g13_1680353130.wav
# Reusing existing connection to aiml-sandbox1.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90200 (88K) [application/octet-stream]
# Saving to: ‘./team_data/5_b20h2g13_1680353130.wav’
#
# 5_b20h2g13_16803531 100%[===================>]  88.09K  --.-KB/s    in 0.005s
#
# 2023-04-04 14:56:18 (18.3 MB/s) - ‘./team_data/5_b20h2g13_1680353130.wav’ saved [90200/90200]
#
# FINISHED --2023-04-04 14:56:18--
# Total wall clock time: 20s
# Downloaded: 176 files, 15M in 0.9s (16.3 MB/s)

# %%
# YOUR CODE HERE to Load data from teamdata folder for extracting all features and labels
team_recorded_features, team_recorded_labels = load_data('/content/team_data')
#team_recorded_labels = np.array(team_recorded_labels).astype('float32')

# %%
print(len(team_recorded_features))
len(studio_recorded_features)
# Out:
# 175
# 3979

# %%
# Combine the features of all voice samples (studio_data and teamdata)
# YOUR CODE HERE
studio_recorded_features.extend(team_recorded_features)
studio_recorded_labels.extend(team_recorded_labels)
print(len(studio_recorded_features))
len(studio_recorded_labels)
# Out:
# 4154
# 4154

# %%
# YOUR CODE HERE to split the combined features into train and test data (Hint: Use train_test_split)
X_train,X_test,y_train, y_test= train_test_split(studio_recorded_features,studio_recorded_labels,test_size=0.2,random_state=40)

# %%
# YOUR CODE HERE to load the dataset with DataLoader
train_set = torch.utils.data.TensorDataset(torch.FloatTensor(X_train), torch.LongTensor(y_train))
test_set = torch.utils.data.TensorDataset(torch.FloatTensor(X_test), torch.LongTensor(y_test))
#loading the train dataset
train_loader = torch.utils.data.DataLoader(train_set,batch_size= batch_size, shuffle= True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size= batch_size, shuffle= True)

# %% [markdown]
# ### b) Classify and download the model (6 Marks)
#
# The goal here is to train and test your model on all voice samples collected in studio and team data
#
# **Evaluation Criteria:**
# * Refine your classifier (if needed)
# * Train your model on the extracted train data
# * Test your model on the extracted test data
# * Save and download the trained model
#
# ### **Expected testing accuracy is above 80%**

# %%
# YOUR CODE HERE for refining your classifier (if needed)
model = Net()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

# %%
# YOUR CODE HERE to train your model
trained_model = train_model(50,model,train_loader, train_set)
# Record loss and accuracy of the train dataset
# Out:
# Epoch 1/50, Training Loss: 0.056, Training Accuracy: 35.841
# Epoch 2/50, Training Loss: 0.037, Training Accuracy: 59.103
# Epoch 3/50, Training Loss: 0.032, Training Accuracy: 65.995
# Epoch 4/50, Training Loss: 0.028, Training Accuracy: 71.351
# Epoch 5/50, Training Loss: 0.025, Training Accuracy: 73.187
# Epoch 6/50, Training Loss: 0.023, Training Accuracy: 77.189
# Epoch 7/50, Training Loss: 0.023, Training Accuracy: 76.587
# Epoch 8/50, Training Loss: 0.020, Training Accuracy: 80.319
# Epoch 9/50, Training Loss: 0.019, Training Accuracy: 80.620
# Epoch 10/50, Training Loss: 0.018, Training Accuracy: 81.162
# Epoch 11/50, Training Loss: 0.018, Training Accuracy: 82.395
# Epoch 12/50, Training Loss: 0.017, Training Accuracy: 83.057
# Epoch 13/50, Training Loss: 0.017, Training Accuracy: 83.780
# Epoch 14/50, Training Loss: 0.014, Training Accuracy: 86.277
# Epoch 15/50, Training Loss: 0.015, Training Accuracy: 85.495
# Epoch 16/50, Training Loss: 0.014, Training Accuracy: 86.639
# Epoch 17/50, Training Loss: 0.014, Training Accuracy: 86.037
# Epoch 18/50, Training Loss: 0.012, Training Accuracy: 87.872
# Epoch 19/50, Training Loss: 0.013, Training Accuracy: 87.421
# Epoch 20/50, Training Loss: 0.012, Training Accuracy: 88.835
# Epoch 21/50, Training Loss: 0.012, Training Accuracy: 88.565
# Epoch 22/50, Training Loss: 0.011, Training Accuracy: 90.310
# Epoch 23/50, Training Loss: 0.011, Training Accuracy: 89.076
# Epoch 24/50, Training Loss: 0.011, Training Accuracy: 89.317
# Epoch 25/50, Training Loss: 0.011, Training Accuracy: 89.768
# Epoch 26/50, Training Loss: 0.010, Training Accuracy: 90.039
# Epoch 27/50, Training Loss: 0.010, Training Accuracy: 90.761
# Epoch 28/50, Training Loss: 0.009, Training Accuracy: 91.724
# Epoch 29/50, Training Loss: 0.009, Training Accuracy: 91.815
# Epoch 30/50, Training Loss: 0.009, Training Accuracy: 91.423
# Epoch 31/50, Training Loss: 0.008, Training Accuracy: 92.206
# Epoch 32/50, Training Loss: 0.008, Training Accuracy: 92.447
# Epoch 33/50, Training Loss: 0.008, Training Accuracy: 92.748
# Epoch 34/50, Training Loss: 0.009, Training Accuracy: 91.724
# Epoch 35/50, Training Loss: 0.008, Training Accuracy: 92.326
# Epoch 36/50, Training Loss: 0.007, Training Accuracy: 93.259
# Epoch 37/50, Training Loss: 0.007, Training Accuracy: 92.657
# Epoch 38/50, Training Loss: 0.007, Training Accuracy: 93.259
# Epoch 39/50, Training Loss: 0.007, Training Accuracy: 93.650
# Epoch 40/50, Training Loss: 0.008, Training Accuracy: 91.453
# Epoch 41/50, Training Loss: 0.006, Training Accuracy: 93.771
# Epoch 42/50, Training Loss: 0.006, Training Accuracy: 93.680
# Epoch 43/50, Training Loss: 0.006, Training Accuracy: 93.410
# Epoch 44/50, Training Loss: 0.006, Training Accuracy: 94.042
# Epoch 45/50, Training Loss: 0.005, Training Accuracy: 95.005
# Epoch 46/50, Training Loss: 0.006, Training Accuracy: 94.944
# Epoch 47/50, Training Loss: 0.006, Training Accuracy: 94.192
# Epoch 48/50, Training Loss: 0.006, Training Accuracy: 94.282
# Epoch 49/50, Training Loss: 0.005, Training Accuracy: 94.914
# Epoch 50/50, Training Loss: 0.006, Training Accuracy: 93.921

# %%
# YOUR CODE HERE to test your model
test_labels, test_predictions = test_model(trained_model, test_loader, test_set)
# Out:
#  Accuracy of test data 84.11552346570397

# %% [markdown]
# **Save your trained model**
#
# * Save the state dictionary of the classifier (use pytorch only), It will be useful in
# integrating model to the web application
#
#  [Hint](https://pytorch.org/tutorials/beginner/saving_loading_models.html)

# %%
### YOUR CODE HERE for saving the CNN model
state = {'net_dict' : trained_model.state_dict()}
torch.save(state, 'final_model.t1')

# %% [markdown]
# Download your trained model using the code below
# * Give the path of model file to download through the browser

# %%
from google.colab import files
files.download('final_model.t1')

# %% [markdown]
# ### c) Deploy and evaluate your model trained on Studio Data + Team Data in the server (6 Marks).
#
# (This can be done on the day of the Hackathon once the login username and password provided by the mentors in the lab)
#
# Deploy your model on the server, check the hackathon document (2-Server Access and File transfer For Voice based e-commerce ordering.pdf) for details.
#
# To order product in user interface, go through the document (3-Hackathon_II Application Interface Documentation.pdf) for details.
#
#
# **Evaluation Criteria: Four consecutive utterances should be predicted correctly by the model**
#
# - There are two stages in the e-commerce ordering application
#     - Ordering Product
#     - Selecting the e-commerce platform
# - If both the stages are cleared as per the evaluation criteria you will get
# complete marks Otherwise, you will see a reduction in the marks
